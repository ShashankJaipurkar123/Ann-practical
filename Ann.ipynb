# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankJaipurkar123/Ann-practical/blob/main/Ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x = dataset.iloc[:, 3:-1]
y = dataset.iloc[:, -1]

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
geogrophy = pd.get_dummies(x['Geography'], drop_first = True)

# %%
gender = pd.get_dummies(x['Gender'], drop_first = True)

# %%
print(geogrophy.head())
# Out:
#    Germany  Spain
# 0        0      0
# 1        0      1
# 2        0      0
# 3        0      0
# 4        0      1

# %%
gender.head()
# Out:
#    Male
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
x = x.drop(['Geography', 'Gender'], axis =1)

# %%
pd.concat([x, geogrophy,gender], axis = 1)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)

# %%
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
x_test.shape
# Out:
# (2000, 8)

# %% [markdown]
# Applying Ann Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import ReLU, LeakyReLU, PReLU, ELU

# %%
from tensorflow.keras.layers import Dropout

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 11, activation = 'relu'))

# %%
classifier.add(Dense(units = 7, activation = 'relu'))

# %%
classifier.add(Dense(units = 7, activation = 'relu'))

# %%
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
classifier.compile(optimizer  = 'adam', loss = 'binary_crossentropy', metrics =['accuracy'])

# %%
import tensorflow as tf
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
model_history = classifier.fit(x_train, y_train, validation_split = 0.33, batch_size = 10, epochs =100, callbacks = early_stopping)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 5s 7ms/step - loss: 0.5144 - accuracy: 0.7946 - val_loss: 0.4653 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4419 - accuracy: 0.7962 - val_loss: 0.4366 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4192 - accuracy: 0.8074 - val_loss: 0.4240 - val_accuracy: 0.8080
# Epoch 4/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4036 - accuracy: 0.8233 - val_loss: 0.4120 - val_accuracy: 0.8133
# Epoch 5/100
# 536/536 [==============================] - 4s 7ms/step - loss: 0.3899 - accuracy: 0.8350 - val_loss: 0.4007 - val_accuracy: 0.8251
# Epoch 6/100
# 536/536 [==============================] - 5s 8ms/step - loss: 0.3763 - accuracy: 0.8433 - val_loss: 0.3880 - val_accuracy: 0.8353
# Epoch 7/100
# ...

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = classifier.predict(x_test)
y_pred = (y_pred >= 0.5)
# Out:
# 63/63 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1540,   55],
#        [ 226,  179]])
